# %%
import numpy as np
import seaborn as sns
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/font_manager.py:229: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
mu, sigma = 0.5, 0.1 
n = 1000
s = np.random.normal(mu, sigma, n)
sns.distplot(s)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import numpy as np
import seaborn as sns
mu, sigma = 14, 2.8
n = 5000
s = np.random.normal(mu, sigma, n)
import matplotlib.pyplot as plt
# %matplotlib inline 
count, bins, ignored = plt.hist(s, 20, density = True)

# %%
import numpy as np
import seaborn as sns
mu, sigma = 14, 2.8
n = 5000
s = np.random.normal(mu, signma, n)
import matplotlib.pyplot as plt 
# %matplotlib inline 
count , bins, ignored = plt.hist(s, 20, density = True)

# %%
import numpy as np
import seaborn as sns
mu, sigma = 14, 2.8 
n = 5000
site = np.random.normal(mu, sigma, n)
import matplotlib.pyplot as plt 
# %matplotlib inline 
count, bins, ignored = plt.hist(s, 20, density = True)

# %%
import numpy as np
import seaborn as sns
mu, signma = 14, 2.8
numbers = 5000
Clouds = np.random.normal(mu, sigma, numbers)
count, bins, ignored = plt.hist(Clouds, 20, density = True)

# %%
import numpy as np
import seaborn as sns
mean_one, sd_one = 5, 3
mean_two, sd_two = 10, 2
Dist_one = np.random.normal(mean_one, sd_one, 1000)
Dist_two = np.random.normal(mean_two, sd_two, 1000)
sns.distplot(Dist_one)
sns.distplot(Dist_two)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
